# %% [markdown]
# # Clase 1: Pasos básicos

# %% [markdown]
# We need `seaborn`, which shall be included it in `requirements.txt` file

# %% [markdown]
# Esto es un texto normal y se debe seleccionar como "Markdown"

# %%
print ('hola')

# %%
# %ls

# %%
# %magic

# %%
nombre = 'my name'
nombre

# %%
# %pwd

# %%
import numpy as np

# %%
N = 50
x = np.random.rand(N)
x

# %%
## Tipos de data en Python

# %%
import math

# %%
type(4)
# Out:
# int

# %%
type (4.0)
# Out:
# float

# %%
math.pi
# Out:
# 3.141592653589793

# %%
type(None)
# Out:
# NoneType

# %%
type(-3)
# Out:
# int

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type(2/3)
# Out:
# float

# %%
numbers = [1,2,3,4,5]

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
sum(numbers)
# Out:
# 15

# %%
suma = sum(numbers)

# %%
suma
# Out:
# 15

# %%
length_numbers = len(numbers)
length_numbers
# Out:
# 5

# %%
type(numbers)
# Out:
# list

# %%
promedio = suma/length_numbers
promedio
# Out:
# 3.0

# %%
# 60 * 10^(-2) = 60 * (10/100) = 60 * 0.01 = 0.6
60*10**(-2)
# Out:
# 0.6

# %%
x = 5
y = 6
if x<y:
    print ('{} es menor que {}'.format(x,y))
else:
    print ('{} es mayor que {}'.format(x,y))
# Out:
# 5 es menor que 6
